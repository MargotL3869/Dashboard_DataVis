# %%
import cdsapi

MON_URL = "https://cds.climate.copernicus.eu/api"
MA_CLE = "e6879404-6927-41a8-8854-16f764f95c0d"

c = cdsapi.Client(url=MON_URL, key=MA_CLE)

print("Découpage en petites tranches de 5 ans pour passer sous le radar...")

# On avance de 5 en 5 (1950, 1955, 1960...)
for annee_debut in range(1950, 2026, 5):
    # L'année de fin est 4 ans plus tard (ex: 1950 + 4 = 1954)
    annee_fin = min(annee_debut + 4, 2025)

    # On crée la liste des années pour cette tranche précise
    annees_tranche = [str(y) for y in range(annee_debut, annee_fin + 1)]
    nom_fichier = f'meteo_france_{annee_debut}_{annee_fin}.nc'

    print(f"⏳ Téléchargement de la période {annee_debut} - {annee_fin}...")

    c.retrieve(
        'reanalysis-era5-single-levels',
        {
            'product_type': 'reanalysis',
            'format': 'netcdf',
            'variable': ['2m_temperature', 'total_precipitation'],
            'year': annees_tranche,
            'month': [str(m).zfill(2) for m in range(1, 13)],
            'day': [str(d).zfill(2) for d in range(1, 32)],
            'time': ['00:00', '06:00', '12:00', '18:00'],
            'area': [51.5, -5.5, 41.0, 10.0],
        },
        nom_fichier
    )
    print(f"✅ {nom_fichier} téléchargé avec succès !")

print("🎉 FINI ! Vous avez triomphé des serveurs de Copernicus !")
# Out:
# Découpage en petites tranches de 5 ans pour passer sous le radar...
# ⏳ Téléchargement de la période 1950 - 1954...
# 2026-02-03 20:29:24,044 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-02-03 20:29:24,047 INFO Request ID is 5287806d-2071-436b-9cba-39f7b73db800
# 2026-02-03 20:29:24,140 INFO status has been updated to accepted
# 2026-02-03 20:29:37,715 INFO status has been updated to running
# 2026-02-03 20:49:55,164 INFO status has been updated to successful
# ✅ meteo_france_1950_1954.nc téléchargé avec succès !
# ⏳ Téléchargement de la période 1955 - 1959...
# 2026-02-03 20:50:04,310 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-02-03 20:50:04,312 INFO Request ID is beadea6d-1c7c-444c-a53f-7121f0c4a6cb
# 2026-02-03 20:50:04,427 INFO status has been updated to accepted
# 2026-02-03 20:50:25,734 INFO status has been updated to running
# 2026-02-03 21:26:39,250 INFO status has been updated to successful
# ✅ meteo_france_1955_1959.nc téléchargé avec succès !
# ⏳ Téléchargement de la période 1960 - 1964...
# 2026-02-03 21:27:05,518 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-02-03 21:27:05,539 INFO Request ID is 0e4b25e2-dc2d-4801-8dc0-e36da108211a
# 2026-02-03 21:27:05,616 INFO status has been updated to accepted
# 2026-02-03 21:27:19,471 INFO status has been updated to running
# 2026-02-04 15:14:36,949 INFO status has been updated to successful
# ✅ meteo_france_1960_1964.nc téléchargé avec succès !
# ⏳ Téléchargement de la période 1965 - 1969...
# 2026-02-04 15:14:50,357 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-02-04 15:14:50,359 INFO Request ID is 5810107f-eb47-40bb-bbbf-f0523dcb95b1
# 2026-02-04 15:14:50,453 INFO status has been updated to accepted
# 2026-02-04 15:14:58,988 INFO status has been updated to running
# 2026-02-04 15:49:52,663 INFO status has been updated to successful
# ✅ meteo_france_1965_1969.nc téléchargé avec succès !
# ⏳ Téléchargement de la période 1970 - 1974...
# 2026-02-04 15:50:00,925 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-02-04 15:50:00,927 INFO Request ID is cc01d256-2b53-4311-acaa-b462df4f1e42
# 2026-02-04 15:50:01,265 INFO status has been updated to accepted
# 2026-02-04 15:50:14,853 INFO status has been updated to running
# 2026-02-04 16:10:26,578 INFO status has been updated to successful
# ✅ meteo_france_1970_1974.nc téléchargé avec succès !
# ⏳ Téléchargement de la période 1975 - 1979...
# 2026-02-04 16:10:33,716 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-02-04 16:10:33,716 INFO Request ID is 18b4c4b2-5094-42eb-a9e5-b830ee448f17
# 2026-02-04 16:10:33,795 INFO status has been updated to accepted
# 2026-02-04 16:10:42,245 INFO status has been updated to running
# 2026-02-04 16:30:58,041 INFO status has been updated to successful
# ✅ meteo_france_1975_1979.nc téléchargé avec succès !
# ⏳ Téléchargement de la période 1980 - 1984...
# 2026-02-04 16:31:05,273 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-02-04 16:31:05,274 INFO Request ID is dc4844eb-c346-482e-ba48-014bd261822e
# 2026-02-04 16:31:05,343 INFO status has been updated to accepted
# 2026-02-04 16:31:13,833 INFO status has been updated to running
# 2026-02-04 16:51:29,257 INFO status has been updated to successful
# ✅ meteo_france_1980_1984.nc téléchargé avec succès !
# ⏳ Téléchargement de la période 1985 - 1989...
# 2026-02-04 16:51:36,877 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-02-04 16:51:36,877 INFO Request ID is 81916155-cbdd-4ebc-998d-7c2bb5f73874
# 2026-02-04 16:51:36,957 INFO status has been updated to accepted
# 2026-02-04 16:51:45,372 INFO status has been updated to running
# 2026-02-04 17:12:01,589 INFO status has been updated to successful
# ✅ meteo_france_1985_1989.nc téléchargé avec succès !
# ⏳ Téléchargement de la période 1990 - 1994...
# 2026-02-04 17:12:10,217 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-02-04 17:12:10,217 INFO Request ID is 4a40753c-51dd-42a5-b126-334a7bdb799b
# 2026-02-04 17:12:10,292 INFO status has been updated to accepted
# 2026-02-04 17:12:18,731 INFO status has been updated to running
# 2026-02-04 17:32:34,080 INFO status has been updated to successful
# ✅ meteo_france_1990_1994.nc téléchargé avec succès !
# ⏳ Téléchargement de la période 1995 - 1999...
# 2026-02-04 17:32:40,689 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-02-04 17:32:40,689 INFO Request ID is 2defd118-5e64-4d8d-bb92-5d26b8738788
# 2026-02-04 17:32:40,814 INFO status has been updated to accepted
# 2026-02-04 17:32:54,346 INFO status has been updated to running
# 2026-02-04 17:51:04,138 INFO status has been updated to successful
# ✅ meteo_france_1995_1999.nc téléchargé avec succès !
# ⏳ Téléchargement de la période 2000 - 2004...
# 2026-02-04 17:51:11,852 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-02-04 17:51:11,852 INFO Request ID is e340e082-594a-4511-bde5-83a5801ef66f
# 2026-02-04 17:51:11,929 INFO status has been updated to accepted
# 2026-02-04 17:51:25,433 INFO status has been updated to running
# 2026-02-04 18:09:35,242 INFO status has been updated to successful
# ✅ meteo_france_2000_2004.nc téléchargé avec succès !
# ⏳ Téléchargement de la période 2005 - 2009...
# 2026-02-04 18:09:43,490 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-02-04 18:09:43,490 INFO Request ID is 19d44cbd-625d-4735-bb06-482e9318cf70
# 2026-02-04 18:09:43,550 INFO status has been updated to accepted
# 2026-02-04 18:09:51,972 INFO status has been updated to running
# 2026-02-04 18:28:07,481 INFO status has been updated to successful
# ✅ meteo_france_2005_2009.nc téléchargé avec succès !
# ⏳ Téléchargement de la période 2010 - 2014...
# 2026-02-04 18:28:34,209 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-02-04 18:28:34,211 INFO Request ID is 7f3c231a-cb40-4078-8a23-b9d79096568e
# 2026-02-04 18:28:34,310 INFO status has been updated to accepted
# 2026-02-04 18:29:49,891 INFO status has been updated to running
